# %%
import pandas as pd 
import matplotlib.pyplot as plt

df = pd.read_csv('premier-league-matches.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       4 df = pd.read_csv('premier-league-matches.csv')
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl.metadata (52 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.62.1-cp313-cp313-macosx_10_13_universal2.whl.metadata (117 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.1 kB)
# Requirement already satisfied: numpy>=1.23 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from matplotlib) (2.4.2)
# Requirement already satisfied: packaging>=20.0 in /Users/katariabhiram/Library/Python/3.13/lib/python/site-packages (from matplotlib) (26.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.8 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.2-py3-none-any.whl.metadata (5.8 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/katariabhiram/Library/Python/3.13/lib/python/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/katariabhiram/Library/Python/3.13/lib/python/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Downloading matplotlib-3.10.8-cp313-cp313-macosx_11_0_arm64.whl (8.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.1/8.1 MB 7.3 MB/s eta 0:00:00a 0:00:01
# Downloading contourpy-1.3.3-cp313-cp313-macosx_11_0_arm64.whl (274 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.62.1-cp313-cp313-macosx_10_13_universal2.whl (2.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 6.2 MB/s eta 0:00:00a 0:00:01
# Downloading kiwisolver-1.5.0-cp313-cp313-macosx_11_0_arm64.whl (64 kB)
# Downloading pillow-12.1.1-cp313-cp313-macosx_11_0_arm64.whl (4.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.7/4.7 MB 6.4 MB/s eta 0:00:00a 0:00:01
# Downloading pyparsing-3.3.2-py3-none-any.whl (122 kB)
# Installing collected packages: pyparsing, pillow, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.3 cycler-0.12.1 fonttools-4.62.1 kiwisolver-1.5.0 matplotlib-3.10.8 pillow-12.1.1 pyparsing-3.3.2
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('premier-league-matches.csv')

# %%
df
# Out:
#        Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0                 1993   1  1992-08-15   Coventry City          2          1
# 1                 1993   1  1992-08-15    Leeds United          2          1
# 2                 1993   1  1992-08-15   Sheffield Utd          2          1
# 3                 1993   1  1992-08-15  Crystal Palace          3          3
# 4                 1993   1  1992-08-15         Arsenal          2          4
# ...                ...  ..         ...             ...        ...        ...
# 12021             2023  38  2023-05-28         Everton          1          0
# 12022             2023  38  2023-05-28  Leicester City          2          1
# 12023             2023  38  2023-05-28     Aston Villa          2          1
# 12024             2023  38  2023-05-28    Leeds United          1          4
# 12025             2023  38  2023-05-28       Brentford          1          0
#
#                   Away FTR
# 0        Middlesbrough   H
# 1            Wimbledon   H
# 2       Manchester Utd   H
# 3            Blackburn   D
# 4         Norwich City   A
# ...                ...  ..
# 12021      Bournemouth   H
# 12022         West Ham   H
# 12023         Brighton   H
# 12024        Tottenham   A
# 12025  Manchester City   H
#
# [12026 rows x 8 columns]

# %%
df['result'] = df['FTR'].map({'H' : 'Home Win', 'A' : 'Away Win', 'D' : 'Draw'})

# %%
df
# Out:
#        Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0                 1993   1  1992-08-15   Coventry City          2          1
# 1                 1993   1  1992-08-15    Leeds United          2          1
# 2                 1993   1  1992-08-15   Sheffield Utd          2          1
# 3                 1993   1  1992-08-15  Crystal Palace          3          3
# 4                 1993   1  1992-08-15         Arsenal          2          4
# ...                ...  ..         ...             ...        ...        ...
# 12021             2023  38  2023-05-28         Everton          1          0
# 12022             2023  38  2023-05-28  Leicester City          2          1
# 12023             2023  38  2023-05-28     Aston Villa          2          1
# 12024             2023  38  2023-05-28    Leeds United          1          4
# 12025             2023  38  2023-05-28       Brentford          1          0
#
#                   Away FTR    result
# 0        Middlesbrough   H  Home Win
# 1            Wimbledon   H  Home Win
# 2       Manchester Utd   H  Home Win
# 3            Blackburn   D      Draw
# 4         Norwich City   A  Away Win
# ...                ...  ..       ...
# 12021      Bournemouth   H  Home Win
# 12022         West Ham   H  Home Win
# 12023         Brighton   H  Home Win
# 12024        Tottenham   A  Away Win
# 12025  Manchester City   H  Home Win
#
# [12026 rows x 9 columns]

# %%
df['result'].value_counts()
# Out:
# result
# Home Win    5519
# Away Win    3410
# Draw        3097
# Name: count, dtype: int64

# %%
df['result'].value_counts(normalize = True).round(3)
# Out:
# result
# Home Win    0.459
# Away Win    0.284
# Draw        0.258
# Name: proportion, dtype: float64

# %%
df
# Out:
#        Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0                 1993   1  1992-08-15   Coventry City          2          1
# 1                 1993   1  1992-08-15    Leeds United          2          1
# 2                 1993   1  1992-08-15   Sheffield Utd          2          1
# 3                 1993   1  1992-08-15  Crystal Palace          3          3
# 4                 1993   1  1992-08-15         Arsenal          2          4
# ...                ...  ..         ...             ...        ...        ...
# 12021             2023  38  2023-05-28         Everton          1          0
# 12022             2023  38  2023-05-28  Leicester City          2          1
# 12023             2023  38  2023-05-28     Aston Villa          2          1
# 12024             2023  38  2023-05-28    Leeds United          1          4
# 12025             2023  38  2023-05-28       Brentford          1          0
#
#                   Away FTR    result
# 0        Middlesbrough   H  Home Win
# 1            Wimbledon   H  Home Win
# 2       Manchester Utd   H  Home Win
# 3            Blackburn   D      Draw
# 4         Norwich City   A  Away Win
# ...                ...  ..       ...
# 12021      Bournemouth   H  Home Win
# 12022         West Ham   H  Home Win
# 12023         Brighton   H  Home Win
# 12024        Tottenham   A  Away Win
# 12025  Manchester City   H  Home Win
#
# [12026 rows x 9 columns]

# %%
df.describe()
# Out:
#        Season_End_Year            Wk     HomeGoals     AwayGoals
# count     12026.000000  12026.000000  12026.000000  12026.000000
# mean       2007.713620     19.730501      1.524364      1.142525
# std           9.072559     11.123916      1.306417      1.133930
# min        1993.000000      1.000000      0.000000      0.000000
# 25%        2000.000000     10.000000      1.000000      0.000000
# 50%        2008.000000     20.000000      1.000000      1.000000
# 75%        2016.000000     29.000000      2.000000      2.000000
# max        2023.000000     42.000000      9.000000      9.000000

# %%
from sklearn.preprocessing import LabelEncoder
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 from sklearn.preprocessing import LabelEncoder
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
# %pip install sklearn
# Out:
# Collecting sklearn
#   Using cached sklearn-0.0.post12.tar.gz (2.6 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [15 lines of output]
#       The 'sklearn' PyPI package is deprecated, use 'scikit-learn'
#       rather than 'sklearn' for pip commands.
#
#       Here is how to fix this error in the main use cases:
#       - use 'pip install scikit-learn' rather than 'pip install sklearn'
#       - replace 'sklearn' by 'scikit-learn' in your pip requirements files
#         (requirements.txt, setup.py, setup.cfg, Pipfile, etc ...)
#       - if the 'sklearn' package is used by one of your dependencies,
#         it would be great if you take some time to track which package uses
#         'sklearn' instead of 'scikit-learn' and report it to their issue tracker
#       - as a last resort, set the environment variable
#         SKLEARN_ALLOW_DEPRECATED_SKLEARN_PACKAGE_INSTALL=True to avoid this error
#
#       More information is available at
#       https://github.com/scikit-learn/sklearn-pypi-package
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install scikit-learn
# Out:
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (11 kB)
# Requirement already satisfied: numpy>=1.24.1 in /Library/Frameworks/Python.framework/Versions/3.13/lib/python3.13/site-packages (from scikit-learn) (2.4.2)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.17.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (62 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Using cached joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Using cached threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Downloading scikit_learn-1.8.0-cp313-cp313-macosx_12_0_arm64.whl (8.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.0/8.0 MB 5.1 MB/s eta 0:00:00a 0:00:01
# Using cached joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading scipy-1.17.1-cp313-cp313-macosx_14_0_arm64.whl (20.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 20.3/20.3 MB 5.7 MB/s eta 0:00:0000:0100:01
# Using cached threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Installing collected packages: threadpoolctl, scipy, joblib, scikit-learn
# Successfully installed joblib-1.5.3 scikit-learn-1.8.0 scipy-1.17.1 threadpoolctl-3.6.0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.0.1
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le_temp = LabelEncoder() 
df['result_encoded'] = le_temp.fit_transform(df['result'])

# %%
df
# Out:
#        Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0                 1993   1  1992-08-15   Coventry City          2          1
# 1                 1993   1  1992-08-15    Leeds United          2          1
# 2                 1993   1  1992-08-15   Sheffield Utd          2          1
# 3                 1993   1  1992-08-15  Crystal Palace          3          3
# 4                 1993   1  1992-08-15         Arsenal          2          4
# ...                ...  ..         ...             ...        ...        ...
# 12021             2023  38  2023-05-28         Everton          1          0
# 12022             2023  38  2023-05-28  Leicester City          2          1
# 12023             2023  38  2023-05-28     Aston Villa          2          1
# 12024             2023  38  2023-05-28    Leeds United          1          4
# 12025             2023  38  2023-05-28       Brentford          1          0
#
#                   Away FTR    result  result_encoded
# 0        Middlesbrough   H  Home Win               2
# 1            Wimbledon   H  Home Win               2
# 2       Manchester Utd   H  Home Win               2
# 3            Blackburn   D      Draw               1
# 4         Norwich City   A  Away Win               0
# ...                ...  ..       ...             ...
# 12021      Bournemouth   H  Home Win               2
# 12022         West Ham   H  Home Win               2
# 12023         Brighton   H  Home Win               2
# 12024        Tottenham   A  Away Win               0
# 12025  Manchester City   H  Home Win               2
#
# [12026 rows x 10 columns]

# %%
df.corr(numeric_only = True)['result_encoded'].sort_values()
# Out:
# AwayGoals         -0.624102
# Season_End_Year   -0.028324
# Wk                 0.016795
# HomeGoals          0.619380
# result_encoded     1.000000
# Name: result_encoded, dtype: float64

# %%
import matplotlib.pyplot as plt 
df['HomeGoals'].hist(bins=10)
plt.title('Distribution of Home Goals')
plt.show()

# %%
df['result'] = df['FTR'].map({'H': 'Home Win', 'A': 'Away Win', 'D': 'Draw'})
df['Date'] = pd.to_datetime(df['Date'])
df = df.sort_values('Date').reset_index(drop=True)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 df['result'] = df['FTR'].map({'H': 'Home Win', 'A': 'Away Win', 'D': 'Draw'})
#       2 df['Date'] = pd.to_datetime(df['Date'])
#       3 df = df.sort_values('Date').reset_index(drop=True)
#
# NameError: name 'df' is not defined

# %%
df
# Out:
#        Season_End_Year  Wk        Date            Home  HomeGoals  AwayGoals  \
# 0                 1993   1  1992-08-15   Coventry City          2          1
# 1                 1993   1  1992-08-15    Leeds United          2          1
# 2                 1993   1  1992-08-15   Sheffield Utd          2          1
# 3                 1993   1  1992-08-15  Crystal Palace          3          3
# 4                 1993   1  1992-08-15         Arsenal          2          4
# ...                ...  ..         ...             ...        ...        ...
# 12021             2023  38  2023-05-28         Everton          1          0
# 12022             2023  38  2023-05-28  Leicester City          2          1
# 12023             2023  38  2023-05-28     Aston Villa          2          1
# 12024             2023  38  2023-05-28    Leeds United          1          4
# 12025             2023  38  2023-05-28       Brentford          1          0
#
#                   Away FTR
# 0        Middlesbrough   H
# 1            Wimbledon   H
# 2       Manchester Utd   H
# 3            Blackburn   D
# 4         Norwich City   A
# ...                ...  ..
# 12021      Bournemouth   H
# 12022         West Ham   H
# 12023         Brighton   H
# 12024        Tottenham   A
# 12025  Manchester City   H
#
# [12026 rows x 8 columns]

# %%
df = pd.read_csv('premier-league-matches.csv')

# %%
import pandas as pd
